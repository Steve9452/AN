# %%
from sympy import Symbol, Rational
from math import exp, cos, sin
from numpy import log as ln
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c473b42cb0f5> in <module>
# ----> 1 from sympy import Symbol, Rational
#       2 from math import exp, cos, sin
#       3 from numpy import log as ln
#
# ModuleNotFoundError: No module named 'sympy'

# %%
pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.8-py3-none-any.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 10.8 MB/s eta 0:00:01
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      |████████████████████████████████| 532 kB 39.0 MB/s eta 0:00:01
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.2.1 sympy-1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
from sympy import Symbol, Rational
from math import exp, cos, sin
from numpy import log as ln
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c473b42cb0f5> in <module>
#       1 from sympy import Symbol, Rational
#       2 from math import exp, cos, sin
# ----> 3 from numpy import log as ln
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 15.6 MB/s eta 0:00:01K     |█                               | 460 kB 15.6 MB/s eta 0:00:01MB 15.6 MB/s eta 0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-1.20.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sympy import Symbol, Rational
from math import exp, cos, sin
from numpy import log as ln

# %%
x = Symbol('x')
y = Symbol('y')

# %%
def lagrangePol(n, xs, ys):
    p = 0
    for k in range(0, n+1):
        p += ys[k] * lagrangeL(n, xs, k)
    return p

# %%
def lagrangeL(n, xs, k):
    L = 1
    for i in range(0, n+1):
        if (i != k):
            L *=(x - xs[i] )/(xs[k] - xs[i])
    return L

# %%
xs = [0, -1, 1]
ys = [1, 2, 2]

pol = lagrangePol(2, xs, ys)
pol.expand()
# Out:
# x**2 + 1

# %%
pol.subs(x, 1)
# Out:
# 2

# %%
def f(x):
    return x + exp(-x**2)*cos(x)

xs = [-2, -1.5, -1]
ys = [f(-2), f(-1.5), f(-1)]

pol = lagrangePol(2, xs, ys)
pol.expand()
# Out:
# 0.352465645513244*x**2 + 2.26378504206903*x + 1.1100855069022

# %%
pol.subs(x, -1)
# Out:
# -0.801233889653587

# %%
def g(x):
    return cos(x)
xs = [0, 0.6]
ys = [g(0), g(0.6)]

pol = lagrangePol(1, xs , ys)
pol.expand()
# Out:
# 1.0 - 0.29110730848387*x

# %%
pol.sub(x, 0.45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a1dc6f789f02> in <module>
# ----> 1 pol.sub(x, 0.45)
#
# AttributeError: 'Add' object has no attribute 'sub'

# %%
pol.subs(x, 0.45)
# Out:
# 0.869001711182259
